# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
data = pd.read_csv('data/diamonds.csv')

# %%
# Первые 5 строк датасета
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# Размер датасета - 53940 строк, 11 колонок
data.shape
# Out:
# (53940, 11)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 53940

# %%
# Список колонок
data.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
# Список колонок с типами данных
data.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
# Проверим наличие пустых значений
# Цикл по колонкам датасета
for col in data.columns:
    # Количество пустых значений - все значения заполнены
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# Unnamed: 0 - 0
# carat - 0
# cut - 0
# color - 0
# clarity - 0
# depth - 0
# table - 0
# price - 0
# x - 0
# y - 0
# z - 0

# %%
# Основные статистические характеристки набора данных
data.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
# Определим уникальные значения для целевого признака
data['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(ax=ax, x='carat', y='price', data=data)

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(ax=ax, x='carat', y='price', data=data, hue='cut')

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(data['depth'])

# %%
data.corr()
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440
# carat        -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094
# depth        -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289
# table        -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344
# price        -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435
# x            -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000
# y            -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701
# z            -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772
#
#                    y         z
# Unnamed: 0 -0.395843 -0.399208
# carat       0.951722  0.953387
# depth      -0.029341  0.094924
# table       0.183760  0.150929
# price       0.865421  0.861249
# x           0.974701  0.970772
# y           1.000000  0.952006
# z           0.952006  1.000000

# %%
data.corr(method='pearson')
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440
# carat        -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094
# depth        -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289
# table        -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344
# price        -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435
# x            -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000
# y            -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701
# z            -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772
#
#                    y         z
# Unnamed: 0 -0.395843 -0.399208
# carat       0.951722  0.953387
# depth      -0.029341  0.094924
# table       0.183760  0.150929
# price       0.865421  0.861249
# x           0.974701  0.970772
# y           1.000000  0.952006
# z           0.952006  1.000000

# %%
data.corr(method='kendall')
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.135543 -0.032338 -0.080543  0.001983 -0.132850
# carat        -0.135543  1.000000  0.019727  0.139149  0.834105  0.960602
# depth        -0.032338  0.019727  1.000000 -0.178682  0.005750 -0.018134
# table        -0.080543  0.139149 -0.178682  1.000000  0.121704  0.143546
# price         0.001983  0.834105  0.005750  0.121704  1.000000  0.830555
# x            -0.132850  0.960602 -0.018134  0.143546  0.830555  1.000000
# y            -0.133234  0.957371 -0.019530  0.138722  0.829333  0.968242
# z            -0.138432  0.951233  0.070946  0.112482  0.819293  0.912580
#
#                    y         z
# Unnamed: 0 -0.133234 -0.138432
# carat       0.957371  0.951233
# depth      -0.019530  0.070946
# table       0.138722  0.112482
# price       0.829333  0.819293
# x           0.968242  0.912580
# y           1.000000  0.911314
# z           0.911314  1.000000

# %%
data.corr(method='spearman')
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.416499 -0.046826 -0.113572 -0.404483 -0.415003
# carat        -0.416499  1.000000  0.030104  0.194980  0.962883  0.996117
# depth        -0.046826  0.030104  1.000000 -0.245061  0.010020 -0.023442
# table        -0.113572  0.194980 -0.245061  1.000000  0.171784  0.202231
# price        -0.404483  0.962883  0.010020  0.171784  1.000000  0.963196
# x            -0.415003  0.996117 -0.023442  0.202231  0.963196  1.000000
# y            -0.416795  0.995572 -0.025425  0.195734  0.962719  0.997895
# z            -0.414872  0.993183  0.103498  0.159878  0.957232  0.987355
#
#                    y         z
# Unnamed: 0 -0.416795 -0.414872
# carat       0.995572  0.993183
# depth      -0.025425  0.103498
# table       0.195734  0.159878
# price       0.962719  0.957232
# x           0.997895  0.987355
# y           1.000000  0.987068
# z           0.987068  1.000000

# %%
fig, ax = plt.subplots(1, 3, sharex='col', sharey='row', figsize=(15,5))
sns.heatmap(data.corr(method='pearson'), ax=ax[0], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='kendall'), ax=ax[1], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='spearman'), ax=ax[2], annot=True, fmt='.2f')
fig.suptitle('Корреляционные матрицы, построенные различными методами')
ax[0].title.set_text('Pearson')
ax[1].title.set_text('Kendall')
ax[2].title.set_text('Spearman')

# %%
sns.jointplot(x='carat', y='price', data=data)
